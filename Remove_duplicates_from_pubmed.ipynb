# %%
import pandas as pd
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Maestría/Investigación/Revisión de Literatura/CSVs
# !ls
# Out:
# /content/drive/MyDrive/Maestría/Investigación/Revisión de Literatura/CSVs
# pubmedsearch.csv	    Scopus_wos_preprocessed.csv
# scopus_health_opendata.csv  wos_health_opendata.txt

# %% [markdown]
# ### Scopus + WoS

# %%
scopus_wos = pd.read_csv('Scopus_wos_preprocessed.csv')
scopus_wos.head(3)
# Out:
#                                              Authors  \
# 0  Cuoghi I.C., da Silva Soares M.F., dos Santos ...
# 1                                      Krauskopf, E.
# 2  Sevillano-Jimenez J., Carrion-Chambilla M., Es...
#
#                                                Title  Year  \
# 0  10-year opportunistic mammographic screening s...  2022
# 1  A bibiliometric analysis of the Journal of Inf...  2018
# 2  A bibliometric analysis of 47-years of researc...  2023
#
#                              Source title Volume Issue Art. No. Page start  \
# 0                Journal of Global Health     12   NaN    04061        NaN
# 1  JOURNAL OF INFECTION AND PUBLIC HEALTH     11     2      NaN        224
# 2  Electronic Journal of General Medicine     20     4    em488        NaN
#
#   Page end  Page count  ...  Document Type  Source  \
# 0      NaN         NaN  ...        Article  Scopus
# 1      229         6.0  ...        Article     WoS
# 2      NaN         NaN  ...        Article  Scopus
#
#                                              Subject                  EID  \
# 0                                                NaN   2-s2.0-85139880822
# 1  Public, Environmental & Occupational Health; I...  WOS:000426961500014
# 2                                                NaN   2-s2.0-85152736068
#
#   duplicatedIn country emailHost        institution    institutionWithCountry  \
# 0          NaN  Brazil    usp.br                NaN                       NaN
# 1          NaN   Chile   unab.cl  Univ Andres Bello  Univ Andres Bello, Chile
# 2          NaN    Peru   upch.pe                NaN                       NaN
#
#                                           authorFull
# 0  Cuoghi I.C., da Silva Soares M.F., dos Santos ...
# 1                                   Krauskopf, Erwin
# 2  Sevillano-Jimenez J., Carrion-Chambilla M., Es...
#
# [3 rows x 42 columns]

# %%
print(f'Number of papers: {scopus_wos.shape[0]}')
# Out:
# Number of papers: 317

# %%
for column in scopus_wos.columns:
  print(column)
# Out:
# Authors
# Title
# Year
# Source title
# Volume
# Issue
# Art. No.
# Page start
# Page end
# Page count
# Cited by
# DOI
# Link
# Affiliations
# Authors with affiliations
# Abstract
# Author Keywords
# Index Keywords
# bothKeywords
# Correspondence Address
# Editors
# Publisher Address
# Conference name
# Conference location
# Conference date
# Publisher
# ISSN
# ISBN
# CODEN
# PubMed ID
# Language of Original Document
# Abbreviated Source Title
# Document Type
# Source
# Subject
# EID
# duplicatedIn
# country
# emailHost
# institution
# institutionWithCountry
# authorFull

# %% [markdown]
# ### Pubmed

# %%
pubmed = pd.read_csv('pubmedsearch.csv')
pubmed.rename(columns={'PMID':'PubMed ID', 'Journal/Book':'Source title', 'Publication Year':'Year'}, inplace=True)
pubmed = pubmed[~pubmed['DOI'].isna()]
pubmed = pubmed[['PubMed ID', 'Title', 'Authors', 'Source title', 'Year', 'PMCID', 'DOI']]
pubmed
# Out:
#      PubMed ID                                              Title  \
# 0     37273013  Regional and national burden of prostate cance...
# 1     37025579  Altered Expression of CYSLTR1 is Associated Wi...
# 2     37019825  Finding a correct species assignment for a Met...
# 3     37013467  A comprehensive analysis of the genetic divers...
# 4     36962476  Challenging the "old boys club" in academia: G...
# ..         ...                                                ...
# 132   17407592  CAMbase--a XML-based bibliographical database ...
# 133   15942755  Mapping and characterization of new EST-derive...
# 134   15643173  Cell lines used in prostate cancer research: a...
# 135   15643172  Cell lines used in prostate cancer research: a...
# 136   15147393  Characterization of open reading frame-express...
#
#                                                Authors  \
# 0    Guzman-Esquivel J, Murillo-Zamora E, Ortiz-Mes...
# 1    Céspedes AG, Conceição MPF, de Bastos DR, de G...
# 2    Troiano E, Larini I, Binati RL, Gatto V, Torri...
# 3    Ceccobelli S, Landi V, Senczuk G, Mastrangelo ...
# 4    Dada S, van Daalen KR, Barrios-Ruiz A, Wu KT, ...
# ..                                                 ...
# 132  Ostermann T, Zillmann H, Raak CK, Buessing A, ...
# 133  Feingold S, Lloyd J, Norero N, Bonierbale M, L...
# 134                                Sobel RE, Sadar MD.
# 135                                Sobel RE, Sadar MD.
# 136  da Mota AF, Sonstegard TS, Van Tassell CP, Sha...
#
#                 Source title  Year        PMCID  \
# 0           Int Urol Nephrol  2023  PMC10240458
# 1        Eur J Breast Health  2023  PMC10071890
# 2             FEMS Yeast Res  2023          NaN
# 3             Genet Sel Evol  2023  PMC10069132
# 4    PLOS Glob Public Health  2022  PMC10021803
# ..                       ...   ...          ...
# 132        Biomed Digit Libr  2007   PMC1853104
# 133         Theor Appl Genet  2005          NaN
# 134                   J Urol  2005          NaN
# 135                   J Urol  2005          NaN
# 136               Anim Genet  2004          NaN
#
#                                       DOI
# 0              10.1007/s11255-023-03653-7
# 1    10.4274/ejbh.galenos.2023.2022-12-10
# 2                  10.1093/femsyr/foad024
# 3              10.1186/s12711-023-00797-z
# 4            10.1371/journal.pgph.0000541
# ..                                    ...
# 132                 10.1186/1742-5581-4-2
# 133             10.1007/s00122-005-2028-2
# 134     10.1097/01.ju.0000149989.01263.dc
# 135     10.1097/01.ju.0000141580.30910.57
# 136      10.1111/j.1365-2052.2004.01139.x
#
# [136 rows x 7 columns]

# %%
print(f'Number of papers: {pubmed.shape[0]}')
# Out:
# Number of papers: 136

# %% [markdown]
# ### Find duplicates

# %%
def check_doi(list1, list2, name1, name2):
  dois_in1_not_in2 = list(set(list1) - set(list2))

  dois_in2_not_in1 = list(set(list2) - set(list1))

  if (len(dois_in1_not_in2) == 0) and (len(dois_in2_not_in1) == 0):
    print('Both files have the same dois!')
  else:
    if (len(dois_in1_not_in2) != 0):
      print(f'{name1} has {len(dois_in1_not_in2)} dois that are not in {name2}')
      #print(f'{name1} has the dois: {dois_in1_not_in2} that are not in {name2}')
    if (len(dois_in2_not_in1) != 0):
      print(f'{name2} has {len(dois_in2_not_in1)} dois that are not in {name1}')
      #print(f'{name2} has the dois: {dois_in2_not_in1} that are not in {name1}')
  return dois_in1_not_in2, dois_in2_not_in1

# %%
list1 = scopus_wos['DOI'].tolist()

list2 = pubmed['DOI'].tolist()

dois_scopus, dois_pubmed = check_doi(list1, list2, name1='Scopus + WoS', name2='Pubmed')
# Out:
# Scopus + WoS has 262 dois that are not in Pubmed
# Pubmed has 102 dois that are not in Scopus + WoS

# %% [markdown]
# ### Merge the files

# %%
pubmed = pubmed[pubmed['DOI'].isin(dois_pubmed)]

# %%
# Concatenate vertically
result = pd.concat([scopus_wos, pubmed], axis=0)
result
# Out:
#                                                Authors  \
# 0    Cuoghi I.C., da Silva Soares M.F., dos Santos ...
# 1                                        Krauskopf, E.
# 2    Sevillano-Jimenez J., Carrion-Chambilla M., Es...
# 3    Daciuk N.I., Quinonez E.G., Poupard M., Vergar...
# 4    Hamzy M.A., de Villiers D., Banner M., Lamprec...
# ..                                                 ...
# 131  Fakhar M, Motazedian MH, Daly D, Lowe CD, Kemp...
# 132  Ostermann T, Zillmann H, Raak CK, Buessing A, ...
# 133  Feingold S, Lloyd J, Norero N, Bonierbale M, L...
# 134                                Sobel RE, Sadar MD.
# 135                                Sobel RE, Sadar MD.
#
#                                                  Title  Year  \
# 0    10-year opportunistic mammographic screening s...  2022
# 1    A bibiliometric analysis of the Journal of Inf...  2018
# 2    A bibliometric analysis of 47-years of researc...  2023
# 3    Access to Grafts in a Liver Transplant Center:...  2018
# 4    Access to top-cited emergency care articles (p...  2019
# ..                                                 ...   ...
# 131  An integrated pipeline for the development of ...  2008
# 132  CAMbase--a XML-based bibliographical database ...  2007
# 133  Mapping and characterization of new EST-derive...  2005
# 134  Cell lines used in prostate cancer research: a...  2005
# 135  Cell lines used in prostate cancer research: a...  2005
#
#                                Source title Volume Issue Art. No. Page start  \
# 0                  Journal of Global Health     12   NaN    04061        NaN
# 1    JOURNAL OF INFECTION AND PUBLIC HEALTH     11     2      NaN        224
# 2    Electronic Journal of General Medicine     20     4    em488        NaN
# 3               Transplantation Proceedings     50     2      NaN        387
# 4     Western Journal of Emergency Medicine     20     3      NaN        460
# ..                                      ...    ...   ...      ...        ...
# 131                            Parasitology    NaN   NaN      NaN        NaN
# 132                       Biomed Digit Libr    NaN   NaN      NaN        NaN
# 133                        Theor Appl Genet    NaN   NaN      NaN        NaN
# 134                                  J Urol    NaN   NaN      NaN        NaN
# 135                                  J Urol    NaN   NaN      NaN        NaN
#
#     Page end  Page count  ...  Source  \
# 0        NaN         NaN  ...  Scopus
# 1        229         6.0  ...     WoS
# 2        NaN         NaN  ...  Scopus
# 3        390         NaN  ...  Scopus
# 4        465         NaN  ...  Scopus
# ..       ...         ...  ...     ...
# 131      NaN         NaN  ...     NaN
# 132      NaN         NaN  ...     NaN
# 133      NaN         NaN  ...     NaN
# 134      NaN         NaN  ...     NaN
# 135      NaN         NaN  ...     NaN
#
#                                                Subject                  EID  \
# 0                                                  NaN   2-s2.0-85139880822
# 1    Public, Environmental & Occupational Health; I...  WOS:000426961500014
# 2                                                  NaN   2-s2.0-85152736068
# 3                                                  NaN   2-s2.0-85044141657
# 4                                                  NaN   2-s2.0-85066853321
# ..                                                 ...                  ...
# 131                                                NaN                  NaN
# 132                                                NaN                  NaN
# 133                                                NaN                  NaN
# 134                                                NaN                  NaN
# 135                                                NaN                  NaN
#
#     duplicatedIn       country     emailHost        institution  \
# 0            NaN        Brazil        usp.br                NaN
# 1            NaN         Chile       unab.cl  Univ Andres Bello
# 2            NaN          Peru       upch.pe                NaN
# 3            NaN     Argentina  yahoo.com.ar                NaN
# 4            NaN  South Africa     uct.ac.za                NaN
# ..           ...           ...           ...                ...
# 131          NaN           NaN           NaN                NaN
# 132          NaN           NaN           NaN                NaN
# 133          NaN           NaN           NaN                NaN
# 134          NaN           NaN           NaN                NaN
# 135          NaN           NaN           NaN                NaN
#
#        institutionWithCountry  \
# 0                         NaN
# 1    Univ Andres Bello, Chile
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 131                       NaN
# 132                       NaN
# 133                       NaN
# 134                       NaN
# 135                       NaN
#
#                                             authorFull       PMCID
# 0    Cuoghi I.C., da Silva Soares M.F., dos Santos ...         NaN
# 1                                     Krauskopf, Erwin         NaN
# 2    Sevillano-Jimenez J., Carrion-Chambilla M., Es...         NaN
# 3    Daciuk N.I., Quinonez E.G., Poupard M., Vergar...         NaN
# 4    Hamzy M.A., de Villiers D., Banner M., Lamprec...         NaN
# ..                                                 ...         ...
# 131                                                NaN         NaN
# 132                                                NaN  PMC1853104
# 133                                                NaN         NaN
# 134                                                NaN         NaN
# 135                                                NaN         NaN
#
# [419 rows x 43 columns]

# %%
result.to_csv('scopus_wos_pubmed.csv')
