# %%
#Dependencies
import pandas as pd
import os

import matplotlib.pyplot as plt
import numpy as np

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Maestría/Investigación/Revisión de Literatura
# !ls
# Out:
# /content/drive/MyDrive/Maestría/Investigación/Revisión de Literatura
#  adding_Pubmed.ipynb
#  CSVs
#  docs_full_paper_review.gsheet
#  filter_selected_papers.ipynb
#  final_docs.csv
#  final_docs.gsheet
#  final_docs_selected.ipynb
#  Guidelines
#  Papers_title_abstract_review.gsheet
#  PDF
#  Plots
# 'Preprocess Summary (Wos, Scopus, Pubmed).gsheet'
# 'Review: Open data in Latin America.gdoc'
#  scopus_wos_pubmed_preprocessed.csv

# %%
import gspread
from google.colab import auth
from google.auth import default

# %%
# Authenticate with Google Sheets API
auth.authenticate_user()
creds, _ = default()
client = gspread.authorize(creds)
#client.list_spreadsheet_files()

# %%
# Replace the values in the following variables with your own values
SPREADSHEET_NAME = 'docs_full_paper_review'
SHEET_NAME = 'docs_final'

# Open the Google Sheets file
sheet = client.open(SPREADSHEET_NAME).worksheet(SHEET_NAME)
# Convert the worksheet data to a list of lists
data = sheet.get_all_values()

# Convert the list of lists to a Pandas DataFrame
docs_final = pd.DataFrame(data[1:], columns=data[0])

docs_final
# Out:
#     Index Exclude                                           Comments  \
# 0      11      No  Data analysis of breast cancer and mammography...
# 1      14      No  Analysis of transplants in Argentina. Using op...
# 2      16      No  Predictive autoregressive model of covid: Data...
# 3      18      No  Covid forecast: Dataset: Open covid-19 data se...
# 4      20      No  Predictive autoregressive model of covid: They...
# ..    ...     ...                                                ...
# 112   374      No                 Publicly available genomic dataset
# 113   376     Yes  We also analysed publicly available RNA-seq da...
# 114   391     Yes  Dataset for Diabetic Nephropathy in Brazil - d...
# 115   406      No  cross-sectional analysis of publicly available...
# 116   411      No  In a publicly available medicines quality data...
#
#                                               Abstract  \
# 0    Background Mammographic screening has been use...
# 1    Background: The number of transplants performe...
# 2    Different countries have adopted various contr...
# 3    The current spreading of the SARS-CoV-2 pandem...
# 4    Here we present a discrete-time-evolution mode...
# ..                                                 ...
# 112  Objectives: High-throughput sequencing of geno...
# 113  MicroRNAs (miRNAs) play an essential role in g...
# 114  This article describes data set of the profile...
# 115  Objective: To determine the association betwee...
# 116  Monitoring the quality of medicines plays a cr...
#
#                                                  Title  \
# 0    10-year opportunistic mammographic screening s...
# 1    Access to Grafts in a Liver Transplant Center:...
# 2    Adaptive Multi-Factor Quantitative Analysis an...
# 3    A Deep Learning Approach to Forecast SARS-CoV-...
# 4    A discrete-time-evolution model to forecast pr...
# ..                                                 ...
# 112  SELAdb: A database of exonic variants in a Bra...
# 113  A genetic variant in microRNA-146a is associat...
# 114  Clinical data and risk factors for diabetic ne...
# 115  Inverse association between altitude and obesi...
# 116  Monitoring the quality of medicines: results f...
#
#                                                Authors  Year  \
# 0    Cuoghi I.C., da Silva Soares M.F., dos Santos ...  2022
# 1    Daciuk N.I., Quinonez E.G., Poupard M., Vergar...  2018
# 2                          Pei Y., Li J., Xu S., Xu Y.  2022
# 3    Aguilar, I.L., Ibanez-Reluz, M., Aguilar, J.C....  2021
# 4                           Curado E.M.F., Curado M.R.  2020
# ..                                                 ...   ...
# 112  Lerario AM, Mohan DR, Montenegro LR, Funari MF...  2020
# 113  Brincas HM, Augusto DG, Mathias C, Cavalli IJ,...  2020
# 114  da Silva EG, Borges Dos Anjos LR, Mendes de Li...  2018
# 115  Woolcott OO, Gutierrez C, Castillo OA, Elashof...  2016
# 116  Hajjou M, Krech L, Lane-Barlow C, Roth L, Prib...  2015
#
#                                           Source title Cited by  \
# 0                             Journal of Global Health        1
# 1                          Transplantation Proceedings        0
# 2                                Frontiers in Medicine        1
# 3    COMPUTATIONAL SCIENCE AND ITS APPLICATIONS, IC...        0
# 4                                             PLoS ONE        3
# ..                                                 ...      ...
# 112                                Clinics (Sao Paulo)
# 113                                     Genet Mol Biol
# 114                                         Data Brief
# 115                            Obesity (Silver Spring)
# 116                                  Am J Trop Med Hyg
#
#                                     DOI  ...  \
# 0                 10.7189/jogh.12.04061  ...
# 1    10.1016/j.transproceed.2017.12.049  ...
# 2              10.3389/fmed.2022.828691  ...
# 3          10.1007/978-3-030-86970-0_22  ...
# 4          10.1371/journal.pone.0241472  ...
# ..                                  ...  ...
# 112          10.6061/clinics/2020/e1913  ...
# 113     10.1590/1678-4685-GMB-2019-0278  ...
# 114           10.1016/j.dib.2018.10.115  ...
# 115                   10.1002/oby.21401  ...
# 116               10.4269/ajtmh.14-0535  ...
#
#                                         Index Keywords  \
# 0    adult; aged; Brazil; breast tumor; cross-secti...
# 1    adult; Argentina; Article; child; comparative ...
# 2    SARS-CoV-2 vaccine; Article; Brazil; coronavir...
# 3
# 4    Article; asymptomatic infection; Brazil; case ...
# ..                                                 ...
# 112
# 113
# 114
# 115
# 116
#
#                                           bothKeywords      Document Type  \
# 0    adult;aged;Brazil;breast tumor;cross-sectional...            Article
# 1    adult;Argentina;Article;child;comparative stud...            Article
# 2    adaptive multi-factor model;COVID-19;social is...            Article
# 3    Deep learning;SARS-CoV-2;Temporal convolutiona...  Proceedings Paper
# 4    Article;asymptomatic infection;Brazil;case stu...            Article
# ..                                                 ...                ...
# 112
# 113
# 114                                                          Data article
# 115                                                               Article
# 116                                                               Article
#
#      Source                                   country  \
# 0    Scopus                                    Brazil
# 1    Scopus                                 Argentina
# 2    Scopus                              Brazil, Peru
# 3       WoS                                      Peru
# 4    Scopus                                    Brazil
# ..      ...                                       ...
# 112  Pubmed                                    Brazil
# 113  Pubmed
# 114  Pubmed
# 115  Pubmed                                      Peru
# 116  Pubmed  Guyana, Peru, Colombia, Ecuador, Bolivia
#
#                                           Dataset name Data type  \
# 0    - Brazilian Institute of Geography and Statist...   Tabular
# 1    Liver transplant recipient: open database CRES...   Tabular
# 2    - COVID-19 Dashboard by the Center for Systems...   Tabular
# 3    -Daily Covid-19 dataset: Ministry of Health in...   Tabular
# 4    Johns Hopkins University: Coronavirus Research...   Tabular
# ..                                                 ...       ...
# 112                                             SELAdb   genomes
# 113
# 114
# 115                                              ENAHO   Tabular
# 116                  Medicines Quality Database (MQDB)   Tabular
#
#     open or credentialed Own Dataset Authors Nationality
# 0                   Open          No              Brazil
# 1                   Open          No           Argentina
# 2                   Open          No               China
# 3                   Open          No        Peru, Brazil
# 4                   Open          No     Brazil, Germany
# ..                   ...         ...                 ...
# 112         Credentialed         Yes         Brazil, USA
# 113
# 114
# 115                 open          No           USA, Peru
# 116                 open         Yes                 N/A
#
# [117 rows x 23 columns]

# %% [markdown]
# ### Filter the file

# %%
# Count the occurrences of each value
value_counts = docs_final.Exclude.value_counts()

# Create the bar plot
ax = value_counts.plot(kind='bar')

# Set labels and title
plt.xlabel('Exclude')
plt.ylabel('Number of Documents')
plt.title('Documents Excluded')

# Add labels to the bars
for i, v in enumerate(value_counts):
    ax.text(i, v, str(v), ha='center', va='bottom')

plt.savefig('Plots/Documents Exclude')
# Display the plot
plt.show()

# %%
# Take the docs with Accepted = Yes
docs_final = docs_final[docs_final['Exclude'] == 'No']

# %%
docs_index = [int(doc_index) for doc_index in docs_final.Index.to_list()]
print(f'The number of accepted is {len(docs_index)}')
# Out:
# The number of accepted is 98

# %% [markdown]
# ### Filter Columns

# %%
# Count the occurrences of each value
value_counts = docs_final.Source.value_counts()

# Create the bar plot
ax = value_counts.plot(kind='bar')

# Set labels and title
plt.xlabel('Database')
plt.ylabel('Number of Documents')
plt.title('Database of Final Accepted Documents')

# Add labels to the bars
for i, v in enumerate(value_counts):
    ax.text(i, v, str(v), ha='center', va='bottom')

plt.savefig('Plots/Documents Per DB')
# Display the plot
plt.show()

# %% [markdown]
# ### Cleaning

# %%
print(f'Initial Columns: {len(docs_final.columns)}')

cols_to_keep = ['Index', 'Abstract', 'Title', 'Authors', 'Year',
                'Source title', 'Cited by', 'DOI', 'Link', 'Affiliations',
                'Author Keywords', 'Index Keywords', 'bothKeywords',
                'country', 'Dataset name', 'Data type',
                'open or credentialed', 'Own Dataset', 'Authors Nationality']

docs_final = docs_final[cols_to_keep]
print(f'Initial Columns: {len(docs_final.columns)}')
# Out:
# Initial Columns: 23
# Initial Columns: 19

# %% [markdown]
# ### Dataset Year

# %%
docs_final.Year = pd.to_numeric(docs_final.Year)

# %%
import matplotlib.pyplot as plt

# Assuming 'docs_final' is your DataFrame with the 'Year' column

# Get the minimum and maximum years from the DataFrame
min_year = docs_final['Year'].min()
max_year = docs_final['Year'].max()
# Count the occurrences of each year in the DataFrame
year_counts = docs_final['Year'].value_counts().sort_index()
# Create a range of years from the minimum to the maximum, inclusive
all_years = range(min_year, max_year + 1)
# Fill missing years with zero counts
year_counts = year_counts.reindex(all_years, fill_value=0)

# Set the figure size
plt.figure(figsize=(10, 6))

# Plot the histogram with customized aesthetics
plt.bar(year_counts.index, year_counts.values, color='steelblue', edgecolor='black', linewidth=0.5)

# Set the labels and title
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Documents', fontsize=12)
plt.title('Documents per Year', fontsize=14)

# Rotate and align the x-axis labels
plt.xticks(rotation=90, ha='center')
# Add labels to each year
plt.xticks(year_counts.index, rotation=90)

# Add gridlines
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Remove the top and right spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Adjust the padding between the axis labels and the plot edges
plt.margins(0.05, 0.1)

# Display the plot
plt.tight_layout()

plt.savefig('Plots/Documents Per Year')
plt.show()

# %% [markdown]
# ### Dataset Country

# %%
countries_dict = {'Argentina':0, 'Bolivia':0, 'Brazil':0, 'Chile':0, 'Colombia':0, 'Ecuador':0, 'Guyana':0, 'Paraguay':0, 'Peru':0, 'Suriname':0, 'Uruguay':0, 'Venezuela':0}

# %%
def clean_countries(countries):
  countries_str = ''
  count = 0
  for country in countries_dict.keys():
    if country.lower() in countries.lower():
      countries_dict[country] += 1
      if count == 0:
        count += 1
        countries_str = country
      else:
        countries_str = countries_str + ', ' + country
  return countries_str

# %%
dtypes_dict = {'Tabular':0, 'Text':0, 'Images': 0, 'Genomics':0}

# %%
def clean_type(dtype):
  dtype_str = ''
  count = 0
  if 'tab' in dtype.lower():
    dtypes_dict['Tabular'] += 1
    if count == 0:
      count += 1
      dtype_str = 'Tabular'
    else:
      dtype_str = dtype_str + ', ' + 'Tabular'
  elif ('image' in dtype.lower()) or ('geotiff' in dtype.lower()):
    dtypes_dict['Images'] += 1
    if count == 0:
      count += 1
      dtype_str = 'Images'
    else:
      dtype_str = dtype_str + ', ' + 'Images'
  elif ('text' in dtype.lower()):
    dtypes_dict['Text'] += 1
    if count == 0:
      count += 1
      dtype_str = 'Text'
    else:
      dtype_str = dtype_str + ', ' + 'Text'
  elif ('genom' in dtype.lower()):
    dtypes_dict['Genomics'] += 1
    if count == 0:
      count += 1
      dtype_str = 'Genomics'
    else:
      dtype_str = dtype_str + ', ' + 'Genomics'

  return dtype_str

# %%
docs_final.country = docs_final.country.apply(clean_countries)
docs_final['open or credentialed'] = docs_final['open or credentialed'].apply(lambda x: 'Open' if x.lower() == 'open' else 'Credentialed')
docs_final['Data type'] = docs_final['Data type'].apply(clean_type)
docs_final.rename(columns={'open or credentialed': 'Open', 'Data type': 'Data_type'}, inplace=True)

# %%
countries_dict
# Out:
# {'Argentina': 11,
#  'Bolivia': 12,
#  'Brazil': 78,
#  'Chile': 12,
#  'Colombia': 24,
#  'Ecuador': 11,
#  'Guyana': 6,
#  'Paraguay': 9,
#  'Peru': 17,
#  'Suriname': 4,
#  'Uruguay': 10,
#  'Venezuela': 11}

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.4.post1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.0)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2022.12.7)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.3)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (1.22.4)

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Create a DataFrame from the dictionary
data = {'Country': list(countries_dict.keys()), 'Value': list(countries_dict.values())}
df = pd.DataFrame(data)

# Load the South America map data
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
south_america = world[world['continent'] == 'South America']

# Merge the map data with the DataFrame
merged = south_america.set_index('name').join(df.set_index('Country'))

# Plot the map
fig, ax = plt.subplots(figsize=(12, 8))
merged.plot(column='Value', cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)

# Set the title
plt.title('South America Map')

# Show the plot
plt.show()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Create a DataFrame from the dictionary
data = {'Country': list(countries_dict.keys()), 'Value': list(countries_dict.values())}
df = pd.DataFrame(data)

# Load the South America map data
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
south_america = world[world['continent'] == 'South America']

# Merge the map data with the DataFrame
merged = south_america.set_index('name').join(df.set_index('Country'))

# Plot the map with a different color map (e.g., 'OrRd')
fig, ax = plt.subplots(figsize=(12, 8))
merged.plot(column='Value', cmap='OrRd', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)

# Set the title
plt.title('Papers product of open datasets in south america')

plt.savefig('Plots/South America Map')

# Show the plot
plt.show()

# %% [markdown]
# ### Dataset Data Type

# %%
import matplotlib.pyplot as plt
import numpy as np

# Convert dictionary values to a list
data = list(dtypes_dict.values())

# List of labels
labels = list(dtypes_dict.keys())

# Create the figure and axes
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(aspect="equal"))

# Define color palette
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']

# Plot the pie chart
wedges, texts, autotexts = ax.pie(data, startangle=-40, colors=colors,
                                  autopct='%1.1f%%', pctdistance=0.85, textprops={'color': 'black', 'fontsize': 12})

# Customize wedge properties
for wedge in wedges:
    wedge.set_edgecolor('white')

# Customize text properties
for text in texts:
    text.set_fontsize(12)

# Annotation properties
bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"), bbox=bbox_props, zorder=0, va="center")

# Annotate each wedge with labels
for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1) / 2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(labels[i], xy=(x, y), xytext=(1.2*np.sign(x), 1.2*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("Data Types Distribution", fontsize=16, fontweight='bold')

plt.tight_layout()

plt.savefig('Plots/Data Types Datasets')
plt.show()

# %% [markdown]
# ### Open Access

# %%
# Count the occurrences of each value
value_counts = docs_final.Open.value_counts()

# Create the bar plot
ax = value_counts.plot(kind='bar')

# Set labels and title
plt.xlabel('Access Type')
plt.ylabel('Number of Documents')
plt.title('Documents Per Access Type')

# Add labels to the bars
for i, v in enumerate(value_counts):
    ax.text(i, v, str(v), ha='center', va='bottom')

plt.savefig('Plots/Documents Per access type')
# Display the plot
plt.show()

# %%
import csv
docs_final.to_csv('final_docs.csv', sep='\t', index=False, encoding='utf-8', quoting=csv.QUOTE_ALL)

# %%
docs_final
# Out:
#     Index                                           Abstract  \
# 0      11  Background Mammographic screening has been use...
# 1      14  Background: The number of transplants performe...
# 2      16  Different countries have adopted various contr...
# 3      18  The current spreading of the SARS-CoV-2 pandem...
# 4      20  Here we present a discrete-time-evolution mode...
# ..    ...                                                ...
# 108   351  Autism spectrum disorder is a neurodevelopment...
# 111   369  Background and objectives: The pandemic of nov...
# 112   374  Objectives: High-throughput sequencing of geno...
# 115   406  Objective: To determine the association betwee...
# 116   411  Monitoring the quality of medicines plays a cr...
#
#                                                  Title  \
# 0    10-year opportunistic mammographic screening s...
# 1    Access to Grafts in a Liver Transplant Center:...
# 2    Adaptive Multi-Factor Quantitative Analysis an...
# 3    A Deep Learning Approach to Forecast SARS-CoV-...
# 4    A discrete-time-evolution model to forecast pr...
# ..                                                 ...
# 108  Exome Evaluation of Autism-Associated Genes in...
# 111  Ensemble learning model for diagnosing COVID-1...
# 112  SELAdb: A database of exonic variants in a Bra...
# 115  Inverse association between altitude and obesi...
# 116  Monitoring the quality of medicines: results f...
#
#                                                Authors  Year  \
# 0    Cuoghi I.C., da Silva Soares M.F., dos Santos ...  2022
# 1    Daciuk N.I., Quinonez E.G., Poupard M., Vergar...  2018
# 2                          Pei Y., Li J., Xu S., Xu Y.  2022
# 3    Aguilar, I.L., Ibanez-Reluz, M., Aguilar, J.C....  2021
# 4                           Curado E.M.F., Curado M.R.  2020
# ..                                                 ...   ...
# 108  da Costa GE, Fernandes GL, Rodrigues JCG, da V...  2022
# 111           AlJame M, Ahmad I, Imtiaz A, Mohammed A.  2020
# 112  Lerario AM, Mohan DR, Montenegro LR, Funari MF...  2020
# 115  Woolcott OO, Gutierrez C, Castillo OA, Elashof...  2016
# 116  Hajjou M, Krech L, Lane-Barlow C, Roth L, Prib...  2015
#
#                                           Source title Cited by  \
# 0                             Journal of Global Health        1
# 1                          Transplantation Proceedings        0
# 2                                Frontiers in Medicine        1
# 3    COMPUTATIONAL SCIENCE AND ITS APPLICATIONS, IC...        0
# 4                                             PLoS ONE        3
# ..                                                 ...      ...
# 108                                      Genes (Basel)
# 111                                Inform Med Unlocked
# 112                                Clinics (Sao Paulo)
# 115                            Obesity (Silver Spring)
# 116                                  Am J Trop Med Hyg
#
#                                     DOI  \
# 0                 10.7189/jogh.12.04061
# 1    10.1016/j.transproceed.2017.12.049
# 2              10.3389/fmed.2022.828691
# 3          10.1007/978-3-030-86970-0_22
# 4          10.1371/journal.pone.0241472
# ..                                  ...
# 108               10.3390/genes13020368
# 111           10.1016/j.imu.2020.100449
# 112          10.6061/clinics/2020/e1913
# 115                   10.1002/oby.21401
# 116               10.4269/ajtmh.14-0535
#
#                                                   Link  \
# 0    https://www.scopus.com/inward/record.uri?eid=2...
# 1    https://www.scopus.com/inward/record.uri?eid=2...
# 2    https://www.scopus.com/inward/record.uri?eid=2...
# 3
# 4    https://www.scopus.com/inward/record.uri?eid=2...
# ..                                                 ...
# 108  https://figshare.com/articles/dataset/Exome_Ev...
# 111  https://www.kaggle.com/datasets/einsteindata4u...
# 112                    http://intranet.fm.usp.br/sela/
# 115  https://www.datosabiertos.gob.pe/dataset/encue...
# 116  https://apps.usp.org/app/worldwide/medQualityD...
#
#                                           Affiliations  \
# 0    CEPAM – Centro de Pesquisa Avançada em Medicin...
# 1    Liver Transplant Unit, Hospital El Cruce, Flor...
# 2    Clinical Data Center, Guangzhou Women and Chil...
# 3    [Luis Aguilar, I] Natl Univ Piura, Dept Math, ...
# 4    Centro Brasileiro de Pesquisas Físicas, Rio de...
# ..                                                 ...
# 108                       Universidade federal do pará
# 111                                  Kuwait University
# 112  Universidade de São Paulo, University of Michigan
# 115  Diabetes and Obesity Research Institute, Cedar...
# 116         Promoting the Quality of Medicines Program
#
#                                        Author Keywords  \
# 0
# 1
# 2    adaptive multi-factor model; COVID-19; social ...
# 3    Deep learning; SARS-CoV-2; Temporal convolutio...
# 4
# ..                                                 ...
# 108
# 111
# 112
# 115
# 116
#
#                                         Index Keywords  \
# 0    adult; aged; Brazil; breast tumor; cross-secti...
# 1    adult; Argentina; Article; child; comparative ...
# 2    SARS-CoV-2 vaccine; Article; Brazil; coronavir...
# 3
# 4    Article; asymptomatic infection; Brazil; case ...
# ..                                                 ...
# 108
# 111
# 112
# 115
# 116
#
#                                           bothKeywords  \
# 0    adult;aged;Brazil;breast tumor;cross-sectional...
# 1    adult;Argentina;Article;child;comparative stud...
# 2    adaptive multi-factor model;COVID-19;social is...
# 3    Deep learning;SARS-CoV-2;Temporal convolutiona...
# 4    Article;asymptomatic infection;Brazil;case stu...
# ..                                                 ...
# 108
# 111
# 112
# 115
# 116
#
#                                       country  \
# 0                                      Brazil
# 1                                   Argentina
# 2                                Brazil, Peru
# 3                                        Peru
# 4                                      Brazil
# ..                                        ...
# 108                                    Brazil
# 111                                    Brazil
# 112                                    Brazil
# 115                                      Peru
# 116  Bolivia, Colombia, Ecuador, Guyana, Peru
#
#                                           Dataset name Data_type  \
# 0    - Brazilian Institute of Geography and Statist...   Tabular
# 1    Liver transplant recipient: open database CRES...   Tabular
# 2    - COVID-19 Dashboard by the Center for Systems...   Tabular
# 3    -Daily Covid-19 dataset: Ministry of Health in...   Tabular
# 4    Johns Hopkins University: Coronavirus Research...   Tabular
# ..                                                 ...       ...
# 108  Exome Evaluation of Autism-Associated Genes in...  Genomics
# 111                  COVID-19 Albert Einstein Hospital   Tabular
# 112                                             SELAdb  Genomics
# 115                                              ENAHO   Tabular
# 116                  Medicines Quality Database (MQDB)   Tabular
#
#              Open Own Dataset Authors Nationality
# 0            Open          No              Brazil
# 1            Open          No           Argentina
# 2            Open          No               China
# 3            Open          No        Peru, Brazil
# 4            Open          No     Brazil, Germany
# ..            ...         ...                 ...
# 108          Open         Yes              Brazil
# 111          Open          No               Kwait
# 112  Credentialed         Yes         Brazil, USA
# 115          Open          No           USA, Peru
# 116          Open         Yes                 N/A
#
# [98 rows x 19 columns]
